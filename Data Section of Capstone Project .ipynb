# %% [markdown]
# # Battle of the Neighborhoods Project:
# ## Figuring Out Where to Open a New Bar In Order To Replicate the Success of an Existing Bar in a Toronto Neighborhood

# %% [markdown]
# ### Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Instructions:
#
# Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.

# %% [markdown]
# **Sources of Data**

# %% [markdown]
#  - **Dataset containing the latitude and longitude coordinates of each neighborhood in Toronto**
#
#      - Source:  This data is available in the form of a wikipedia table at the link:  https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
#      - Description of dataset:  The dataset contains information about postal codes, boroughs, neighborhoods, latitude, and longitude.
#      - Data wrangling requirements:
#
#
#
#  - **Dataset containing the latitude and longitude coordinates of each neighborhood in Manhattan**
#      - Source:
#      - Description of dataset:
#      - Data wrangling requirements:

# %% [markdown]
# **New Dataframes to be Created to Support the Analysis**

# %% [markdown]
#  - **Dataframe containing the latitude and longitude coordinates of each neighborhood in Toronto and Manhattan**
#
#      - Source:
#      - Description of dataset:
#      - Data wrangling requirements:
#
#
#
#  - **Dataframe containing . . .**
#      - Source:
#      - Description of dataset:
#      - Data wrangling requirements:
